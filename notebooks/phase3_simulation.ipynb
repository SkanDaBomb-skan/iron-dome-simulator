# %% [markdown]
# # Phase 3 — Iron Dome C2 Dashboard
# ## Simulateur Iron Dome — PFA ENSTAB
# ### Real-time multi-threat tracking, threat assessment & interception

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../src'))
sys.path.insert(0, os.path.abspath('../src/dashboard'))
from iron_dome_dashboard import IronDomeDashboard

# %%
dashboard = IronDomeDashboard()
dashboard.show()
# Out:
# ...
#     'data': [{'line': {'color': '#22c55e', 'width': 4},
#          …
